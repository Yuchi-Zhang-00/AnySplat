# %%
import PIL.Image
from PIL import Image

# %%
path = '/home/yuchi/Desktop/test1-o.jpg'
img = Image.open(path)
if img.mode == 'RGBA':
    # Convert RGBA to RGB by removing alpha channel
    img = img.convert('RGB')
img = img.resize((448,448))
img.save(path)

# %%
path = '/home/yuchi/projects/AnySplat/examples/new-desk/table_mask.png'
img = Image.open(path)
if img.mode == 'RGBA':
    # Convert RGBA to RGB by removing alpha channel
    img = img.convert('RGB')
img = img.resize((448,448))
img.save(path)
